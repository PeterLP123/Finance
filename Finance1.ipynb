# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526476
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422663
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410791
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.404602
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  135.068588
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.270172
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  132.133820
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  131.116043
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a = [1,2,3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker=["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.515213  19.081619   88.454201    7.643214  28.520000
# 2010-01-05    6.526477  18.850788   88.688347    7.656429  28.174999
# 2010-01-06    6.422665  18.844105   88.750801    7.534643  28.165001
# 2010-01-07    6.410789  18.797262   89.125435    7.520714  28.094999
# 2010-01-08    6.453412  18.449358   89.422028    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.404556  50.318058  358.332703  131.970001  53.439999
# 2020-12-28  135.068604  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.270172  50.967743  360.721527  134.869995  54.130001
# 2020-12-30  132.133820  51.259632  361.236206  133.720001  54.439999
# 2020-12-31  131.116043  51.636269  363.071625  132.690002  54.840000
#
# ...

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.515213  19.081619  88.454201  7.643214  28.520000  113.330002
# 2010-01-05  6.526477  18.850788  88.688347  7.656429  28.174999  113.629997
# 2010-01-06  6.422665  18.844105  88.750801  7.534643  28.165001  113.709999
# 2010-01-07  6.410789  18.797262  89.125435  7.520714  28.094999  114.190002
# 2010-01-08  6.453412  18.449358  89.422028  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2020-12-24  130.404556  50.318058  358.332703  131.970001  53.439999
# 2020-12-28  135.068604  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.270172  50.967743  360.721527  134.869995  54.130001
# 2020-12-30  132.133820  51.259632  361.236206  133.720001  54.439999
# 2020-12-31  131.116043  51.636269  363.071625  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
#stocks.to_csv("stocksF1.csv")

# %%
#stocks = pd.read_csv("stocksF1.csv")

# %%
#stocks

# %%
#stocks = pd.read_csv("stocksF1.csv",header=[0,1])

# %%
#stocks

# %%
#stocks = pd.read_csv("stocksF1.csv",header=[0,1],index_col=[0])
#stocks

# %%
#stocks = pd.read_csv("stocksF1.csv",header=[0,1],index_col=[0], parse_dates=[0])
#stocks

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.515213        19.081619         88.454201
# 2010-01-05           6.526477        18.850788         88.688347
# 2010-01-06           6.422665        18.844105         88.750801
# 2010-01-07           6.410789        18.797262         89.125435
# 2010-01-08           6.453412        18.449358         89.422028
# ...                       ...              ...               ...
# 2020-12-24         130.404556        50.318058        358.332703
# 2020-12-28         135.068604        50.995991        361.411041
# 2020-12-29         133.270172        50.967743        360.721527
# 2020-12-30         132.133820        51.259632        361.236206
# 2020-12-31         131.116043        51.636269        363.071625
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.515213  19.081619   88.454201    7.643214  28.520000
# 2010-01-05    6.526477  18.850788   88.688347    7.656429  28.174999
# 2010-01-06    6.422665  18.844105   88.750801    7.534643  28.165001
# 2010-01-07    6.410789  18.797262   89.125435    7.520714  28.094999
# 2010-01-08    6.453412  18.449358   89.422028    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.404556  50.318058  358.332703  131.970001  53.439999
# 2020-12-28  135.068604  50.995991  361.411041  136.690002  54.160000
# 2020-12-29  133.270172  50.967743  360.721527  134.869995  54.130001
# 2020-12-30  132.133820  51.259632  361.236206  133.720001  54.439999
# 2020-12-31  131.116043  51.636269  363.071625  132.690002  54.840000
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.738985    33.224921   184.819318    33.777537    41.320121
# std      24.752378     8.441915    70.762975    24.572747     6.808527
# min       5.846674    16.890404    80.476761     6.858929    25.014999
# 25%      15.286290    27.444929   116.627312    17.484285    37.660000
# 50%      24.686472    32.771210   178.655731    26.987499    41.759998
# 75%      41.160427    38.815666   245.609756    43.007500    45.549999
# max     135.068604    54.743851   363.071625   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-428-4d420f08d23f>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.subtract(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl["% Change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
del aapl["% Change 2"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl.rename(columns = {'% Change':'Daily Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  Daily Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN           NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215      0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786     -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929     -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000      0.664833  0.050000
# ...                ...         ...       ...           ...       ...
# 2020-12-24  131.970001  130.960007  1.009995      0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001      3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007     -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994     -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999     -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
#Last Business day
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  Daily Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN           NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215      0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786     -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929     -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000      0.664833  0.050000
# ...                ...         ...       ...           ...       ...
# 2020-12-24  131.970001  130.960007  1.009995      0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001      3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007     -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994     -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999     -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
del aapl["Daily Change"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.050000
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999
#
# [2769 rows x 4 columns]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
#                 AAPL      lag1       Diff      Diff2
# Date
# 2010-01-06 -0.015906  0.001729 -10.216000 -10.216000
# 2010-01-07 -0.001849 -0.015906  -0.885624  -0.885624
# 2010-01-08  0.006648 -0.001849  -4.589552  -4.589552
# 2010-01-11 -0.008821  0.006648  -2.335692  -2.335692
# 2010-01-12 -0.011375 -0.008821   0.278106   0.278106
# ...              ...       ...        ...        ...
# 2020-12-24  0.007712 -0.006976  -2.097822  -2.097822
# 2020-12-28  0.035766  0.007712   3.673294   3.673294
# 2020-12-29 -0.013315  0.035766  -1.385595  -1.385595
# 2020-12-30 -0.008527 -0.013315  -0.368138  -0.368138
# 2020-12-31 -0.007703 -0.008527  -0.104344  -0.104344
#
# [2767 rows x 4 columns]

# %%
plt.hist(ret.AAPL, bins=50)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL     0.001191
# lag1     0.001194
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
#Variance
var_daily=ret.var()
var_daily
# Out:
# AAPL     0.000318
# lag1     0.000318
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
#Standard Deviation
std_daily=np.sqrt(var_daily)
std_daily
# Out:
# AAPL     0.017846
# lag1     0.017845
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
ret.std()
# Out:
# AAPL     0.017846
# lag1     0.017845
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
#252 working days
annual_mean_ret = daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL     0.300085
# lag1     0.300944
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
annual_var_ret = var_daily*252
annual_var_ret
# Out:
# AAPL     0.080255
# lag1     0.080248
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
annual_std_ret = np.sqrt(annual_var_ret)
annual_std_ret
# Out:
# AAPL     0.283293
# lag1     0.283281
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL     0.283293
# lag1     0.283281
# Diff          NaN
# Diff2         NaN
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks=yf.download(ticker, start = "2010-01-01",end="2021-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
plt.title("Risk/return",fontsize=25)
plt.show()

# %%
fruits = ["apple","banana","mango"]
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS   0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS   0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM   0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO    0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT  0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY   0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #Simple and log returns

# %%
df = pd.DataFrame(index = [2016, 2017 , 2018], data=[100,50,95], columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
#Misleading mean returns
# Out:
# 144.0

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2022-12-23  382.910004
# 2022-12-27  381.399994
# 2022-12-28  376.660004
# 2022-12-29  383.440002
# 2022-12-30  382.429993
#
# [7536 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy_roll = spy.rolling(window=10)
spy_roll = spy_roll.mean()
spy_roll.head(20)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875
# 1993-02-22  44.146875
# 1993-02-23  44.018750
# 1993-02-24  43.978125
# 1993-02-25  43.940625
# 1993-02-26  43.887500

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2022-12-23  384.750000
# 2022-12-27  383.089996
# 2022-12-28  382.154999
# 2022-12-29  382.154999
# 2022-12-30  381.914993
#
# [7536 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2022-12-23  401.970001
# 2022-12-27  401.970001
# 2022-12-28  399.399994
# 2022-12-29  389.630005
# 2022-12-30  386.230011
#
# [7536 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(20)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875
# 1993-02-22  44.96875
# 1993-02-23  44.93750
# 1993-02-24  44.93750
# 1993-02-25  44.93750
# 1993-02-26  44.59375

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
#Exponential Weighted Moving Average
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2022-12-23  382.910004  387.845001  400.793601  391.451550
# 2022-12-27  381.399994  388.320400  400.600251  391.252509
# 2022-12-28  376.660004  388.517200  400.398551  390.963549
# 2022-12-29  383.440002  388.763400  400.184901  390.814568
# 2022-12-30  382.429993  389.042000  399.918951  390.648537
#
# [7536 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday
# ...                ...         ...         ...         ...        ...
# 2022-12-23  382.910004  387.845001  400.793601  391.451550     Friday
# 2022-12-27  381.399994  388.320400  400.600251  391.252509    Tuesday
# 2022-12-28  376.660004  388.517200  400.398551  390.963549  Wednesday
# 2022-12-29  383.440002  388.763400  400.184901  390.814568   Thursday
# 2022-12-30  382.429993  389.042000  399.918951  390.648537     Friday
#
# [7536 rows x 5 columns]

# %%
spy["Quarter"]=spy.index.quarter

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2022-12-23  382.910004  387.845001  400.793601  391.451550     Friday        4
# 2022-12-27  381.399994  388.320400  400.600251  391.252509    Tuesday        4
# 2022-12-28  376.660004  388.517200  400.398551  390.963549  Wednesday        4
# 2022-12-29  383.440002  388.763400  400.184901  390.814568   Thursday        4
# 2022-12-30  382.429993  389.042000  399.918951  390.648537     Friday        4
#
# ...

# %%
spy2 = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy2=spy2.Close.to_frame()

# %%
all_days = pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")

# %%
spy2 = spy2.reindex(all_days)
spy2
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
#Forward fill
spy2.fillna(method="ffill")
#Backward fill
#spy2.fillna(method="bfill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %% [markdown]
# # Cummulative Returns, Drawdowns

# %%
apple = yf.download("AAPL")
apple = apple.Close.to_frame()
apple
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2022-12-23  131.860001
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [10603 rows x 1 columns]

# %%
apple["d_return"]=np.log(apple/apple.shift(1))
apple
# Out:
#                  Close  d_return
# Date
# 1980-12-12    0.128348       NaN
# 1980-12-15    0.121652 -0.053581
# 1980-12-16    0.112723 -0.076231
# 1980-12-17    0.115513  0.024450
# 1980-12-18    0.118862  0.028580
# ...                ...       ...
# 2022-12-23  131.860001 -0.002802
# 2022-12-27  130.029999 -0.013976
# 2022-12-28  126.040001 -0.031166
# 2022-12-29  129.610001  0.027931
# 2022-12-30  129.929993  0.002466
#
# [10603 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_return
# Date
# 1980-12-15    0.121652 -0.053581
# 1980-12-16    0.112723 -0.076231
# 1980-12-17    0.115513  0.024450
# 1980-12-18    0.118862  0.028580
# 1980-12-19    0.126116  0.059239
# ...                ...       ...
# 2022-12-23  131.860001 -0.002802
# 2022-12-27  130.029999 -0.013976
# 2022-12-28  126.040001 -0.031166
# 2022-12-29  129.610001  0.027931
# 2022-12-30  129.929993  0.002466
#
# [10602 rows x 2 columns]

# %%
apple.d_return.sum()
# Out:
# 6.92000579704391

# %%
np.exp(apple.d_return.sum())
# Out:
# 1012.3258630153844

# %%
apple["cummreturn"]=apple.d_return.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_return   cummreturn
# Date
# 1980-12-15    0.121652 -0.053581     0.947829
# 1980-12-16    0.112723 -0.076231     0.878261
# 1980-12-17    0.115513  0.024450     0.899998
# 1980-12-18    0.118862  0.028580     0.926092
# 1980-12-19    0.126116  0.059239     0.982610
# ...                ...       ...          ...
# 2022-12-23  131.860001 -0.002802  1027.363168
# 2022-12-27  130.029999 -0.013976  1013.105042
# 2022-12-28  126.040001 -0.031166   982.017701
# 2022-12-29  129.610001  0.027931  1009.832703
# 2022-12-30  129.929993  0.002466  1012.325863
#
# [10602 rows x 3 columns]

# %%
apple.cummreturn.plot(figsize=(12,8),fontsize=15,title="Apple buy and hold strategy")
plt.show()

# %%
apple.d_return.mean()*252
# Out:
# 0.16448231096539004

# %%
apple.d_return.std()*np.sqrt(252)
# Out:
# 0.4557979410666854

# %%
#Calculate drawdown
apple["cummmax"]=apple.cummreturn.cummax()
apple
# Out:
#                  Close  d_return   cummreturn      cummmax
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829
# 1980-12-17    0.115513  0.024450     0.899998     0.947829
# 1980-12-18    0.118862  0.028580     0.926092     0.947829
# 1980-12-19    0.126116  0.059239     0.982610     0.982610
# ...                ...       ...          ...          ...
# 2022-12-23  131.860001 -0.002802  1027.363168  1418.097708
# 2022-12-27  130.029999 -0.013976  1013.105042  1418.097708
# 2022-12-28  126.040001 -0.031166   982.017701  1418.097708
# 2022-12-29  129.610001  0.027931  1009.832703  1418.097708
# 2022-12-30  129.929993  0.002466  1012.325863  1418.097708
#
# [10602 rows x 4 columns]

# %%
apple[["cummreturn","cummmax"]].plot(figsize=(12,8),fontsize=15,title="Apple buy and hold strategy with cummyulative max")
plt.show()

# %%
apple["drawdown"]=apple.cummmax-apple.cummreturn
apple
# Out:
#                  Close  d_return   cummreturn      cummmax    drawdown
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513  0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862  0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116  0.059239     0.982610     0.982610    0.000000
# ...                ...       ...          ...          ...         ...
# 2022-12-23  131.860001 -0.002802  1027.363168  1418.097708  390.734539
# 2022-12-27  130.029999 -0.013976  1013.105042  1418.097708  404.992665
# 2022-12-28  126.040001 -0.031166   982.017701  1418.097708  436.080007
# 2022-12-29  129.610001  0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993  0.002466  1012.325863  1418.097708  405.771845
#
# [10602 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 436.0800066130546

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2022-12-28 00:00:00')

# %%
apple.loc[(apple.index<='2022-12-28')]
# Out:
#                  Close  d_return   cummreturn      cummmax    drawdown
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513  0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862  0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116  0.059239     0.982610     0.982610    0.000000
# ...                ...       ...          ...          ...         ...
# 2022-12-21  135.449997  0.023530  1055.333970  1418.097708  362.763737
# 2022-12-22  132.229996 -0.024060  1030.245918  1418.097708  387.851790
# 2022-12-23  131.860001 -0.002802  1027.363168  1418.097708  390.734539
# 2022-12-27  130.029999 -0.013976  1013.105042  1418.097708  404.992665
# 2022-12-28  126.040001 -0.031166   982.017701  1418.097708  436.080007
#
# [10600 rows x 5 columns]

# %%
apple["drawdown%"]=apple.drawdown/apple.cummmax
apple
# Out:
#                  Close  d_return   cummreturn      cummmax    drawdown  \
# Date
# 1980-12-15    0.121652 -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723 -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513  0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862  0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116  0.059239     0.982610     0.982610    0.000000
# ...                ...       ...          ...          ...         ...
# 2022-12-23  131.860001 -0.002802  1027.363168  1418.097708  390.734539
# 2022-12-27  130.029999 -0.013976  1013.105042  1418.097708  404.992665
# 2022-12-28  126.040001 -0.031166   982.017701  1418.097708  436.080007
# 2022-12-29  129.610001  0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993  0.002466  1012.325863  1418.097708  405.771845
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_return  cummreturn   cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652 -0.053581    0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723 -0.076231    0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513  0.024450    0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862  0.028580    0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116  0.059239    0.982610  0.982610  0.000000   0.000000
# ...              ...       ...         ...       ...       ...        ...
# 1997-12-17  0.124442 -0.026549    0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326 -0.009008    0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210 -0.009090    0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862 -0.027778    0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513 -0.028580    0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# # SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2022-12-23  131.860001
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [8062 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2022-12-23  131.860001  144.131800  150.515600
# 2022-12-27  130.029999  143.964799  150.157800
# 2022-12-28  126.040001  143.637399  149.764699
# 2022-12-29  129.610001  143.354599  149.412100
# 2022-12-30  129.929993  143.075999  149.062199
#
# [8062 rows x 3 columns]

# %%
data.plot(figsize=(12,8),fontsize=15, title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l))
# Out:
# <AxesSubplot: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),fontsize=15, title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l))
# Out:
# <AxesSubplot: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2022-12-23  131.860001  144.131800  150.515600
# 2022-12-27  130.029999  143.964799  150.157800
# 2022-12-28  126.040001  143.637399  149.764699
# 2022-12-29  129.610001  143.354599  149.412100
# 2022-12-30  129.929993  143.075999  149.062199
#
# [7963 rows x 3 columns]

# %%
data["position"]=np.where(data.sma_s>data.sma_l,1,-1)
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2022-12-23  131.860001  144.131800  150.515600        -1
# 2022-12-27  130.029999  143.964799  150.157800        -1
# 2022-12-28  126.040001  143.637399  149.764699        -1
# 2022-12-29  129.610001  143.354599  149.412100        -1
# 2022-12-30  129.929993  143.075999  149.062199        -1
#
# [7963 rows x 4 columns]

# %%
#Use secondary y position for position
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),fontsize=15, title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l), secondary_y="position")
# Out:
# <AxesSubplot: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
#Buy and hold strategy
data["returnb&h"]=np.log(data.Close/data.Close.shift(1))
data
# Out:
#                  Close       sma_s       sma_l  position  returnb&h
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1        NaN
# 1991-05-24    0.409598    0.530960    0.513538         1   0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1   0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1   0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1   0.013209
# ...                ...         ...         ...       ...        ...
# 2022-12-23  131.860001  144.131800  150.515600        -1  -0.002802
# 2022-12-27  130.029999  143.964799  150.157800        -1  -0.013976
# 2022-12-28  126.040001  143.637399  149.764699        -1  -0.031166
# 2022-12-29  129.610001  143.354599  149.412100        -1   0.027931
# 2022-12-30  129.929993  143.075999  149.062199        -1   0.002466
#
# [7963 rows x 5 columns]

# %%
data["strategy"]=data.position.shift(1)*data["returnb&h"]

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1        NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1   0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1   0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1   0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1   0.013209  0.013209
# ...                ...         ...         ...       ...        ...       ...
# 2022-12-23  131.860001  144.131800  150.515600        -1  -0.002802  0.002802
# 2022-12-27  130.029999  143.964799  150.157800        -1  -0.013976  0.013976
# 2022-12-28  126.040001  143.637399  149.764699        -1  -0.031166  0.031166
# 2022-12-29  129.610001  143.354599  149.412100        -1   0.027931 -0.027931
# 2022-12-30  129.929993  143.075999  149.062199        -1   0.002466 -0.002466
#
# [7963 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnb&h","strategy"]].sum()
# Out:
# returnb&h    5.776058
# strategy     2.107834
# dtype: float64

# %%
data[["returnb&h","strategy"]].sum().apply(np.exp) #What 1$ invested would be worth today
# Out:
# returnb&h    322.485345
# strategy       8.230396
# dtype: float64

# %%
data[["returnb&h","strategy"]].std()*np.sqrt(252) #Volatility
# Out:
# returnb&h    0.440242
# strategy     0.440373
# dtype: float64

# %%
data.Close.plot(figsize=(12,8),fontsize=15)
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data["position2"]=np.where(data.sma_s>data.sma_l,1,0)
data["strategy2"]=data.position2.shift(1)*data["returnb&h"]
data
# Out:
#                  Close       sma_s       sma_l  position  returnb&h  strategy  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1   0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1   0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1   0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1   0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1  -0.013209 -0.013209
# ...                ...         ...         ...       ...        ...       ...
# 2022-12-23  131.860001  144.131800  150.515600        -1  -0.002802  0.002802
# 2022-12-27  130.029999  143.964799  150.157800        -1  -0.013976  0.013976
# 2022-12-28  126.040001  143.637399  149.764699        -1  -0.031166  0.031166
# 2022-12-29  129.610001  143.354599  149.412100        -1   0.027931 -0.027931
# 2022-12-30  129.929993  143.075999  149.062199        -1   0.002466 -0.002466
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returnb&h","strategy2"]].sum()
# Out:
# returnb&h    5.759575
# strategy2    3.925463
# dtype: float64

# %%
data[["returnb&h","strategy2"]].sum().apply(np.exp) #What 1$ invested would be worth today
# Out:
# returnb&h    317.213451
# strategy2     50.676542
# dtype: float64

# %%
data[["returnb&h","strategy2"]].std()*np.sqrt(252) #Volatility
# Out:
# returnb&h    0.440261
# strategy2    0.340403
# dtype: float64

# %% [markdown]
# ### Strategy 2 is better than strategy 1

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.440391
# strategy2    0.340403
# dtype: float64

# %% [markdown]
# ## Creating Functions

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close/data.Close.shift(1))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data["position"]=np.where(data.SMA_S>data.SMA_L,1,-1)
    data["strategy"]=data.position.shift(1)*data["returns"]
    data.dropna(inplace=True)
    ret=np.exp(data.strategy.sum())
    std=data.strategy.std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("SPY","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (4.766371508372407, 0.18787947185958592)

# %% [markdown]
# ## Creating Classes

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()

    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close/data.Close.shift(1))
        data["SMA_S"]=data.Close.rolling(int(self.SMA_S)).mean()
        data["SMA_L"]=data.Close.rolling(int(self.SMA_L)).mean()
        data.dropna(inplace=True)
        self.data2=data

        return data

    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data.SMA_S>data.SMA_L,1,-1)
        data["strategy"]=data.position.shift(1)*data["returns"]
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data

        ret=np.exp(data.strategy.sum())
        std=data.strategy.std()*np.sqrt(252)
    
        return round(perf,6), round(outperf,6)

    def plot_results(self):
        if self.results is None:
            print("No results to plot yet. Run test_results.")
        else:
            title="{} | SMA_S: {} | SMA_L: {}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title,figsize=(12,8))

# %%
tester = SMABacktester("SPY",50,100,"2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
